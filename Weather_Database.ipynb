# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []

# %%
# Print length of city list
len(cities)
# Out:
# 0

# %%
from citipy import citipy

# %%
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Import the requests library
import requests

#Import the API library
from config import weather_api_key

#Import traceback
import traceback

# %%
len(cities)
# Out:
# 642

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# Create an empty list to hold the weather data/
city_data = []

#Print the beginning of the logging. 
print("Beginning Data Retrieval      ")
print("------------------------------")

# Create counters
record_count = 1
set_count = 1
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# ------------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
        
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        try:
            city_rain_inches = city_weather["rain"]["3h"]
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather["snow"]["3h"]
        except KeyError:
            city_snow_inches = 0   
         
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather": city_weather_description,
                          "Rain": city_rain_inches,
                          "Snow": city_snow_inches,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        # traceback.print_exc()
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | zhangye
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | provideniya
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | henties bay
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | saint-philippe
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | yevlax
# Processing Record 10 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 1 | manicore
# Processing Record 12 of Set 1 | port hardy
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | tuktoyaktuk
# Processing Record 15 of Set 1 | kawana waters
# City not found. Skipping...
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | maloshuyka
# City not found. Skipping...
# Processing Record 18 of Set 1 | qaanaaq
# Processing Record 19 of Set 1 | alta floresta
# Processing Record 20 of Set 1 | palu
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | fort nelson
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | concepcion
# Processing Record 25 of Set 1 | riyadh
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | betki
# City not found. Skipping...
# Processing Record 29 of Set 1 | chuy
# Processing Record 30 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 1 | vanavara
# Processing Record 32 of Set 1 | marawi
# Processing Record 33 of Set 1 | rio gallegos
# Processing Record 34 of Set 1 | buluang
# Processing Record 35 of Set 1 | caravelas
# Processing Record 36 of Set 1 | agirish
# Processing Record 37 of Set 1 | margate
# Processing Record 38 of Set 1 | butaritari
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | grand gaube
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | georgetown
# Processing Record 43 of Set 1 | bluff
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 1 | kodiak
# Processing Record 47 of Set 1 | port lincoln
# Processing Record 48 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 1 | victoria
# Processing Record 50 of Set 1 | souillac
# Processing Record 1 of Set 2 | victor harbor
# Processing Record 2 of Set 2 | port alfred
# Processing Record 3 of Set 2 | leningradskiy
# Processing Record 4 of Set 2 | sao jose da coroa grande
# Processing Record 5 of Set 2 | kristiansund
# Processing Record 6 of Set 2 | lebu
# Processing Record 7 of Set 2 | beira
# Processing Record 8 of Set 2 | taoudenni
# Processing Record 9 of Set 2 | kaitangata
# Processing Record 10 of Set 2 | longyearbyen
# Processing Record 11 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 2 | dieppe bay
# City not found. Skipping...
# Processing Record 13 of Set 2 | sakaide
# Processing Record 14 of Set 2 | thompson
# Processing Record 15 of Set 2 | new norfolk
# Processing Record 16 of Set 2 | mahajanga
# Processing Record 17 of Set 2 | aviles
# Processing Record 18 of Set 2 | formosa do rio preto
# Processing Record 19 of Set 2 | cidreira
# Processing Record 20 of Set 2 | hermanus
# Processing Record 21 of Set 2 | prien
# Processing Record 22 of Set 2 | barrow
# Processing Record 23 of Set 2 | ribeira grande
# Processing Record 24 of Set 2 | roald
# Processing Record 25 of Set 2 | isangel
# Processing Record 26 of Set 2 | avarua
# Processing Record 27 of Set 2 | maputo
# Processing Record 28 of Set 2 | mokhsogollokh
# Processing Record 29 of Set 2 | prince rupert
# Processing Record 30 of Set 2 | hamilton
# Processing Record 31 of Set 2 | coruripe
# Processing Record 32 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 2 | soyaux
# Processing Record 34 of Set 2 | tabukiniberu
# City not found. Skipping...
# Processing Record 35 of Set 2 | vestmanna
# Processing Record 36 of Set 2 | guerrero negro
# Processing Record 37 of Set 2 | racale
# Processing Record 38 of Set 2 | manokwari
# Processing Record 39 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 2 | alappuzha
# Processing Record 41 of Set 2 | olinda
# Processing Record 42 of Set 2 | leiyang
# Processing Record 43 of Set 2 | sant feliu de guixols
# Processing Record 44 of Set 2 | vad
# Processing Record 45 of Set 2 | laguna
# Processing Record 46 of Set 2 | ulladulla
# Processing Record 47 of Set 2 | dikson
# Processing Record 48 of Set 2 | east london
# Processing Record 49 of Set 2 | bandiagara
# Processing Record 50 of Set 2 | lazarev
# Processing Record 1 of Set 3 | ojinaga
# Processing Record 2 of Set 3 | tilichiki
# Processing Record 3 of Set 3 | pangnirtung
# Processing Record 4 of Set 3 | rio grande
# Processing Record 5 of Set 3 | korla
# Processing Record 6 of Set 3 | kenora
# Processing Record 7 of Set 3 | santa rosa
# Processing Record 8 of Set 3 | kavieng
# Processing Record 9 of Set 3 | kismayo
# Processing Record 10 of Set 3 | muisne
# Processing Record 11 of Set 3 | vaini
# Processing Record 12 of Set 3 | lavrentiya
# Processing Record 13 of Set 3 | marsa matruh
# Processing Record 14 of Set 3 | cairns
# Processing Record 15 of Set 3 | chernyshevskiy
# Processing Record 16 of Set 3 | yate
# Processing Record 17 of Set 3 | skala
# Processing Record 18 of Set 3 | ola
# Processing Record 19 of Set 3 | san pedro
# Processing Record 20 of Set 3 | castro
# Processing Record 21 of Set 3 | peniche
# Processing Record 22 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 3 | karratha
# Processing Record 24 of Set 3 | ahwa
# Processing Record 25 of Set 3 | penarth
# Processing Record 26 of Set 3 | khasan
# Processing Record 27 of Set 3 | los llanos de aridane
# Processing Record 28 of Set 3 | hilo
# Processing Record 29 of Set 3 | fairbanks
# Processing Record 30 of Set 3 | clyde river
# Processing Record 31 of Set 3 | port macquarie
# Processing Record 32 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 3 | salinopolis
# Processing Record 34 of Set 3 | hobyo
# Processing Record 35 of Set 3 | severnoye
# Processing Record 36 of Set 3 | maningrida
# Processing Record 37 of Set 3 | vestmannaeyjar
# Processing Record 38 of Set 3 | inta
# Processing Record 39 of Set 3 | kampot
# Processing Record 40 of Set 3 | sur
# Processing Record 41 of Set 3 | chuncheng
# Processing Record 42 of Set 3 | santa isabel do rio negro
# Processing Record 43 of Set 3 | effingham
# Processing Record 44 of Set 3 | ascension
# Processing Record 45 of Set 3 | ixtapa
# Processing Record 46 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 3 | la ronge
# Processing Record 48 of Set 3 | nargana
# Processing Record 49 of Set 3 | westport
# Processing Record 50 of Set 3 | tabas
# Processing Record 1 of Set 4 | san mateo del mar
# Processing Record 2 of Set 4 | dingle
# Processing Record 3 of Set 4 | iquique
# Processing Record 4 of Set 4 | mount gambier
# Processing Record 5 of Set 4 | hualmay
# Processing Record 6 of Set 4 | atasu
# Processing Record 7 of Set 4 | logan
# Processing Record 8 of Set 4 | bambous virieux
# Processing Record 9 of Set 4 | norman wells
# Processing Record 10 of Set 4 | puerto ayora
# Processing Record 11 of Set 4 | ostrovnoy
# Processing Record 12 of Set 4 | escanaba
# Processing Record 13 of Set 4 | sunnyside
# Processing Record 14 of Set 4 | morehead
# Processing Record 15 of Set 4 | erzin
# Processing Record 16 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 4 | ust-kalmanka
# Processing Record 18 of Set 4 | beringovskiy
# Processing Record 19 of Set 4 | aklavik
# Processing Record 20 of Set 4 | gorontalo
# Processing Record 21 of Set 4 | namatanai
# Processing Record 22 of Set 4 | erenhot
# Processing Record 23 of Set 4 | hailar
# Processing Record 24 of Set 4 | carnarvon
# Processing Record 25 of Set 4 | seoul
# Processing Record 26 of Set 4 | oktyabrskiy
# Processing Record 27 of Set 4 | san carlos de bariloche
# Processing Record 28 of Set 4 | kapaa
# Processing Record 29 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 4 | bonavista
# Processing Record 31 of Set 4 | khatanga
# Processing Record 32 of Set 4 | freeport
# Processing Record 33 of Set 4 | tiksi
# Processing Record 34 of Set 4 | tocopilla
# Processing Record 35 of Set 4 | lixourion
# Processing Record 36 of Set 4 | saskylakh
# Processing Record 37 of Set 4 | hithadhoo
# Processing Record 38 of Set 4 | avera
# Processing Record 39 of Set 4 | obo
# Processing Record 40 of Set 4 | altay
# Processing Record 41 of Set 4 | biysk
# Processing Record 42 of Set 4 | adrar
# Processing Record 43 of Set 4 | weinan
# Processing Record 44 of Set 4 | bambanglipuro
# Processing Record 45 of Set 4 | porto santo
# Processing Record 46 of Set 4 | safford
# Processing Record 47 of Set 4 | jyvaskyla
# Processing Record 48 of Set 4 | chokurdakh
# Processing Record 49 of Set 4 | kaniama
# Processing Record 50 of Set 4 | slave lake
# Processing Record 1 of Set 5 | providencia
# Processing Record 2 of Set 5 | vardo
# Processing Record 3 of Set 5 | iqaluit
# Processing Record 4 of Set 5 | hobart
# Processing Record 5 of Set 5 | bom jesus da lapa
# Processing Record 6 of Set 5 | lompoc
# Processing Record 7 of Set 5 | te anau
# Processing Record 8 of Set 5 | severo-kurilsk
# Processing Record 9 of Set 5 | puri
# Processing Record 10 of Set 5 | moorhead
# Processing Record 11 of Set 5 | alyangula
# Processing Record 12 of Set 5 | esperance
# Processing Record 13 of Set 5 | ajdabiya
# Processing Record 14 of Set 5 | tanete
# Processing Record 15 of Set 5 | touros
# Processing Record 16 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 17 of Set 5 | sitka
# Processing Record 18 of Set 5 | konstanz
# Processing Record 19 of Set 5 | zulueta
# Processing Record 20 of Set 5 | namibe
# Processing Record 21 of Set 5 | mount isa
# Processing Record 22 of Set 5 | beloha
# Processing Record 23 of Set 5 | dunedin
# Processing Record 24 of Set 5 | timbiras
# Processing Record 25 of Set 5 | luganville
# Processing Record 26 of Set 5 | vila do maio
# Processing Record 27 of Set 5 | sadabad
# Processing Record 28 of Set 5 | sibolga
# Processing Record 29 of Set 5 | acarau
# Processing Record 30 of Set 5 | bethel
# Processing Record 31 of Set 5 | anapskaya
# Processing Record 32 of Set 5 | tezu
# Processing Record 33 of Set 5 | maridi
# Processing Record 34 of Set 5 | pimentel
# Processing Record 35 of Set 5 | praia da vitoria
# Processing Record 36 of Set 5 | pisco
# Processing Record 37 of Set 5 | saint-pacome
# City not found. Skipping...
# Processing Record 38 of Set 5 | nikolskoye
# Processing Record 39 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 5 | beyneu
# Processing Record 41 of Set 5 | ambilobe
# Processing Record 42 of Set 5 | upernavik
# Processing Record 43 of Set 5 | port elizabeth
# Processing Record 44 of Set 5 | cherskiy
# Processing Record 45 of Set 5 | ahipara
# Processing Record 46 of Set 5 | torbay
# Processing Record 47 of Set 5 | urucara
# Processing Record 48 of Set 5 | pevek
# Processing Record 49 of Set 5 | mayo
# Processing Record 50 of Set 5 | ponta do sol
# Processing Record 1 of Set 6 | tasiilaq
# Processing Record 2 of Set 6 | aldan
# Processing Record 3 of Set 6 | ilo
# Processing Record 4 of Set 6 | buchanan
# Processing Record 5 of Set 6 | poshtove
# Processing Record 6 of Set 6 | posse
# Processing Record 7 of Set 6 | saint combs
# City not found. Skipping...
# Processing Record 8 of Set 6 | tadine
# Processing Record 9 of Set 6 | paraiso
# Processing Record 10 of Set 6 | mahebourg
# Processing Record 11 of Set 6 | lusaka
# Processing Record 12 of Set 6 | evensk
# Processing Record 13 of Set 6 | thayetmyo
# Processing Record 14 of Set 6 | ville-marie
# Processing Record 15 of Set 6 | luoyang
# Processing Record 16 of Set 6 | santa cruz
# Processing Record 17 of Set 6 | dedza
# Processing Record 18 of Set 6 | mar del plata
# Processing Record 19 of Set 6 | de-kastri
# Processing Record 20 of Set 6 | santa isabel
# Processing Record 21 of Set 6 | sobolevo
# Processing Record 22 of Set 6 | paris
# Processing Record 23 of Set 6 | vigrestad
# Processing Record 24 of Set 6 | sao filipe
# Processing Record 25 of Set 6 | lahij
# Processing Record 26 of Set 6 | montreal
# Processing Record 27 of Set 6 | mazulskiy
# City not found. Skipping...
# Processing Record 28 of Set 6 | linxi
# Processing Record 29 of Set 6 | shenjiamen
# Processing Record 30 of Set 6 | dire
# Processing Record 31 of Set 6 | wasilla
# Processing Record 32 of Set 6 | yablonovo
# Processing Record 33 of Set 6 | along
# Processing Record 34 of Set 6 | bacuit
# City not found. Skipping...
# Processing Record 35 of Set 6 | terrace
# Processing Record 36 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 37 of Set 6 | hurghada
# Processing Record 38 of Set 6 | bowmore
# Processing Record 39 of Set 6 | santa fe
# Processing Record 40 of Set 6 | port keats
# Processing Record 41 of Set 6 | lalibela
# Processing Record 42 of Set 6 | ilulissat
# Processing Record 43 of Set 6 | lethem
# Processing Record 44 of Set 6 | zhezkazgan
# Processing Record 45 of Set 6 | morondava
# Processing Record 46 of Set 6 | darnah
# Processing Record 47 of Set 6 | viedma
# Processing Record 48 of Set 6 | gemena
# Processing Record 49 of Set 6 | bako
# Processing Record 50 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 1 of Set 7 | utena
# Processing Record 2 of Set 7 | tonj
# Processing Record 3 of Set 7 | portsmouth
# Processing Record 4 of Set 7 | san quintin
# Processing Record 5 of Set 7 | ugoofaaru
# Processing Record 6 of Set 7 | lillesand
# Processing Record 7 of Set 7 | key west
# Processing Record 8 of Set 7 | yidu
# Processing Record 9 of Set 7 | la paz
# Processing Record 10 of Set 7 | krugersdorp
# Processing Record 11 of Set 7 | lorengau
# Processing Record 12 of Set 7 | ketchikan
# Processing Record 13 of Set 7 | faya
# Processing Record 14 of Set 7 | atlantic city
# Processing Record 15 of Set 7 | indapur
# Processing Record 16 of Set 7 | dwarka
# Processing Record 17 of Set 7 | winfield
# Processing Record 18 of Set 7 | asau
# Processing Record 19 of Set 7 | jinsha
# Processing Record 20 of Set 7 | cacoal
# Processing Record 21 of Set 7 | staryy nadym
# Processing Record 22 of Set 7 | eyl
# Processing Record 23 of Set 7 | turkistan
# Processing Record 24 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 7 | camacari
# Processing Record 26 of Set 7 | bow island
# Processing Record 27 of Set 7 | san patricio
# Processing Record 28 of Set 7 | san ramon
# Processing Record 29 of Set 7 | pontianak
# Processing Record 30 of Set 7 | katsuura
# Processing Record 31 of Set 7 | januaria
# Processing Record 32 of Set 7 | bathsheba
# Processing Record 33 of Set 7 | constitucion
# Processing Record 34 of Set 7 | dharchula
# Processing Record 35 of Set 7 | gisborne
# Processing Record 36 of Set 7 | acapulco
# Processing Record 37 of Set 7 | ginir
# Processing Record 38 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 7 | peleduy
# Processing Record 40 of Set 7 | darien
# Processing Record 41 of Set 7 | quatre cocos
# Processing Record 42 of Set 7 | kibala
# Processing Record 43 of Set 7 | calbuco
# Processing Record 44 of Set 7 | yarmouth
# Processing Record 45 of Set 7 | klaksvik
# Processing Record 46 of Set 7 | cayenne
# Processing Record 47 of Set 7 | buqayq
# City not found. Skipping...
# Processing Record 48 of Set 7 | manono
# Processing Record 49 of Set 7 | kahului
# Processing Record 50 of Set 7 | bengkulu
# Processing Record 1 of Set 8 | ust-omchug
# Processing Record 2 of Set 8 | poco verde
# Processing Record 3 of Set 8 | luorong
# Processing Record 4 of Set 8 | kortkeros
# Processing Record 5 of Set 8 | kharitonovo
# Processing Record 6 of Set 8 | chapais
# Processing Record 7 of Set 8 | potgietersrus
# City not found. Skipping...
# Processing Record 8 of Set 8 | rosetown
# Processing Record 9 of Set 8 | mehamn
# Processing Record 10 of Set 8 | seddon
# Processing Record 11 of Set 8 | kavaratti
# Processing Record 12 of Set 8 | trelew
# Processing Record 13 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 14 of Set 8 | budesti
# Processing Record 15 of Set 8 | airai
# Processing Record 16 of Set 8 | nishihara
# Processing Record 17 of Set 8 | bahia blanca
# Processing Record 18 of Set 8 | mombetsu
# Processing Record 19 of Set 8 | puerto madryn
# Processing Record 20 of Set 8 | ndioum
# Processing Record 21 of Set 8 | tornio
# Processing Record 22 of Set 8 | lunca de jos
# Processing Record 23 of Set 8 | ternate
# Processing Record 24 of Set 8 | padang
# Processing Record 25 of Set 8 | san marcos
# Processing Record 26 of Set 8 | abha
# Processing Record 27 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 8 | merced
# Processing Record 29 of Set 8 | mirabad
# Processing Record 30 of Set 8 | huarmey
# Processing Record 31 of Set 8 | husavik
# Processing Record 32 of Set 8 | mucuri
# Processing Record 33 of Set 8 | coquimbo
# Processing Record 34 of Set 8 | russell
# Processing Record 35 of Set 8 | piacabucu
# Processing Record 36 of Set 8 | bundaberg
# Processing Record 37 of Set 8 | miramar
# Processing Record 38 of Set 8 | pilar
# Processing Record 39 of Set 8 | casa nova
# Processing Record 40 of Set 8 | oranjestad
# Processing Record 41 of Set 8 | akyab
# Processing Record 42 of Set 8 | gornozavodsk
# Processing Record 43 of Set 8 | vostok
# Processing Record 44 of Set 8 | gold coast
# Processing Record 45 of Set 8 | sinnamary
# Processing Record 46 of Set 8 | nioro
# Processing Record 47 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 8 | clarence town
# Processing Record 49 of Set 8 | hofn
# Processing Record 50 of Set 8 | luderitz
# Processing Record 1 of Set 9 | ahuimanu
# Processing Record 2 of Set 9 | magaria
# Processing Record 3 of Set 9 | lagoa
# Processing Record 4 of Set 9 | warwick
# Processing Record 5 of Set 9 | abalak
# Processing Record 6 of Set 9 | puerto escondido
# Processing Record 7 of Set 9 | naze
# Processing Record 8 of Set 9 | ko samui
# Processing Record 9 of Set 9 | klyuchi
# Processing Record 10 of Set 9 | willmar
# Processing Record 11 of Set 9 | chumikan
# Processing Record 12 of Set 9 | ranfurly
# Processing Record 13 of Set 9 | cianorte
# Processing Record 14 of Set 9 | netrakona
# Processing Record 15 of Set 9 | bolshiye kaybitsy
# City not found. Skipping...
# Processing Record 16 of Set 9 | hailey
# Processing Record 17 of Set 9 | college
# Processing Record 18 of Set 9 | koroni
# Processing Record 19 of Set 9 | baracoa
# Processing Record 20 of Set 9 | ilesha
# Processing Record 21 of Set 9 | tagusao
# Processing Record 22 of Set 9 | tuatapere
# Processing Record 23 of Set 9 | havoysund
# Processing Record 24 of Set 9 | noumea
# Processing Record 25 of Set 9 | santarem
# Processing Record 26 of Set 9 | male
# Processing Record 27 of Set 9 | wewak
# Processing Record 28 of Set 9 | talladega
# Processing Record 29 of Set 9 | shreveport
# Processing Record 30 of Set 9 | kudahuvadhoo
# Processing Record 31 of Set 9 | comodoro rivadavia
# Processing Record 32 of Set 9 | muroto
# Processing Record 33 of Set 9 | hermiston
# Processing Record 34 of Set 9 | remontnoye
# Processing Record 35 of Set 9 | alofi
# Processing Record 36 of Set 9 | bakaly
# Processing Record 37 of Set 9 | mizan teferi
# Processing Record 38 of Set 9 | singaraja
# Processing Record 39 of Set 9 | necochea
# Processing Record 40 of Set 9 | challapalle
# Processing Record 41 of Set 9 | bitung
# Processing Record 42 of Set 9 | bubaque
# Processing Record 43 of Set 9 | fortuna
# Processing Record 44 of Set 9 | luancheng
# Processing Record 45 of Set 9 | manggar
# Processing Record 46 of Set 9 | trairi
# Processing Record 47 of Set 9 | kalmunai
# Processing Record 48 of Set 9 | coihaique
# Processing Record 49 of Set 9 | saint-andre-les-vergers
# Processing Record 50 of Set 9 | ust-ilimsk
# Processing Record 1 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 10 | yar-sale
# Processing Record 3 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 4 of Set 10 | kruisfontein
# Processing Record 5 of Set 10 | miraflores
# Processing Record 6 of Set 10 | najran
# Processing Record 7 of Set 10 | port augusta
# Processing Record 8 of Set 10 | la asuncion
# Processing Record 9 of Set 10 | lata
# Processing Record 10 of Set 10 | yialos
# City not found. Skipping...
# Processing Record 11 of Set 10 | gornopravdinsk
# Processing Record 12 of Set 10 | warri
# Processing Record 13 of Set 10 | khorixas
# Processing Record 14 of Set 10 | aswan
# Processing Record 15 of Set 10 | acajutla
# Processing Record 16 of Set 10 | jingdezhen
# Processing Record 17 of Set 10 | corowa
# Processing Record 18 of Set 10 | hit
# Processing Record 19 of Set 10 | barcelos
# Processing Record 20 of Set 10 | road town
# Processing Record 21 of Set 10 | lago da pedra
# Processing Record 22 of Set 10 | springbok
# Processing Record 23 of Set 10 | malayal
# Processing Record 24 of Set 10 | kupang
# Processing Record 25 of Set 10 | minas
# Processing Record 26 of Set 10 | grindavik
# Processing Record 27 of Set 10 | navirai
# Processing Record 28 of Set 10 | pitimbu
# Processing Record 29 of Set 10 | yulara
# Processing Record 30 of Set 10 | verkhoyansk
# Processing Record 31 of Set 10 | kingsville
# Processing Record 32 of Set 10 | fagersta
# Processing Record 33 of Set 10 | bukachacha
# Processing Record 34 of Set 10 | byron bay
# Processing Record 35 of Set 10 | maarianhamina
# Processing Record 36 of Set 10 | khandbari
# Processing Record 37 of Set 10 | iskateley
# Processing Record 38 of Set 10 | sumenep
# Processing Record 39 of Set 10 | codrington
# Processing Record 40 of Set 10 | talas
# Processing Record 41 of Set 10 | narsaq
# Processing Record 42 of Set 10 | talnakh
# Processing Record 43 of Set 10 | villafranca de los barros
# Processing Record 44 of Set 10 | faanui
# Processing Record 45 of Set 10 | banepa
# Processing Record 46 of Set 10 | venice
# Processing Record 47 of Set 10 | taltal
# Processing Record 48 of Set 10 | yakima
# Processing Record 49 of Set 10 | phalodi
# Processing Record 50 of Set 10 | khristoforovo
# City not found. Skipping...
# Processing Record 1 of Set 11 | vallenar
# Processing Record 2 of Set 11 | pochutla
# Processing Record 3 of Set 11 | paamiut
# Processing Record 4 of Set 11 | auray
# Processing Record 5 of Set 11 | jalu
# Processing Record 6 of Set 11 | nemuro
# Processing Record 7 of Set 11 | farakka
# Processing Record 8 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 9 of Set 11 | karpathos
# Processing Record 10 of Set 11 | raton
# Processing Record 11 of Set 11 | nome
# Processing Record 12 of Set 11 | kieta
# Processing Record 13 of Set 11 | goba
# Processing Record 14 of Set 11 | jacareacanga
# Processing Record 15 of Set 11 | haines junction
# Processing Record 16 of Set 11 | zilupe
# Processing Record 17 of Set 11 | zwedru
# Processing Record 18 of Set 11 | watsa
# Processing Record 19 of Set 11 | semey
# Processing Record 20 of Set 11 | port moresby
# Processing Record 21 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 11 | killybegs
# Processing Record 23 of Set 11 | bismil
# Processing Record 24 of Set 11 | port-de-paix
# City not found. Skipping...
# Processing Record 25 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 11 | valparaiso
# Processing Record 27 of Set 11 | bilma
# Processing Record 28 of Set 11 | charlestown
# Processing Record 29 of Set 11 | shebunino
# Processing Record 30 of Set 11 | shizilu
# Processing Record 31 of Set 11 | kultuk
# Processing Record 32 of Set 11 | anshun
# Processing Record 33 of Set 11 | saint george
# Processing Record 34 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 35 of Set 11 | nador
# Processing Record 36 of Set 11 | zhanatas
# City not found. Skipping...
# Processing Record 37 of Set 11 | menongue
# Processing Record 38 of Set 11 | cabo san lucas
# Processing Record 39 of Set 11 | bulgan
# Processing Record 40 of Set 11 | makarska
# Processing Record 41 of Set 11 | narrabri
# Processing Record 42 of Set 11 | trapani
# Processing Record 43 of Set 11 | pinan
# Processing Record 44 of Set 11 | zakharovo
# Processing Record 45 of Set 11 | atar
# Processing Record 46 of Set 11 | verdalsora
# City not found. Skipping...
# Processing Record 47 of Set 11 | alice springs
# Processing Record 48 of Set 11 | jertih
# Processing Record 49 of Set 11 | sao joao da barra
# Processing Record 50 of Set 11 | khani
# Processing Record 1 of Set 12 | salalah
# Processing Record 2 of Set 12 | timiryazevskiy
# Processing Record 3 of Set 12 | kusk
# City not found. Skipping...
# Processing Record 4 of Set 12 | port hedland
# Processing Record 5 of Set 12 | inirida
# Processing Record 6 of Set 12 | chatham
# Processing Record 7 of Set 12 | tatawin
# Processing Record 8 of Set 12 | bousso
# Processing Record 9 of Set 12 | sosnovo-ozerskoye
# Processing Record 10 of Set 12 | lakselv
# Processing Record 11 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 12 of Set 12 | paulo ramos
# Processing Record 13 of Set 12 | rorvik
# Processing Record 14 of Set 12 | verona
# Processing Record 15 of Set 12 | baguinge
# Processing Record 16 of Set 12 | makakilo city
# Processing Record 17 of Set 12 | batagay
# Processing Record 18 of Set 12 | hvolsvollur
# Processing Record 19 of Set 12 | zaraza
# Processing Record 20 of Set 12 | banmo
# City not found. Skipping...
# Processing Record 21 of Set 12 | majene
# Processing Record 22 of Set 12 | kulhudhuffushi
# Processing Record 23 of Set 12 | golfito
# Processing Record 24 of Set 12 | jumla
# Processing Record 25 of Set 12 | alakurtti
# Processing Record 26 of Set 12 | raga
# Processing Record 27 of Set 12 | hami
# Processing Record 28 of Set 12 | agira
# Processing Record 29 of Set 12 | el pinon
# Processing Record 30 of Set 12 | elban
# Processing Record 31 of Set 12 | ballina
# Processing Record 32 of Set 12 | raudeberg
# Processing Record 33 of Set 12 | ibra
# Processing Record 34 of Set 12 | charqueada
# Processing Record 35 of Set 12 | yilan
# Processing Record 36 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 37 of Set 12 | poum
# Processing Record 38 of Set 12 | disna
# Processing Record 39 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 12 | kargil
# Processing Record 41 of Set 12 | moerai
# Processing Record 42 of Set 12 | requena
# Processing Record 43 of Set 12 | lynn haven
# Processing Record 44 of Set 12 | vila franca do campo
# Processing Record 45 of Set 12 | palmer
# Processing Record 46 of Set 12 | biak
# Processing Record 47 of Set 12 | cheremkhovo
# Processing Record 48 of Set 12 | sardarshahr
# Processing Record 49 of Set 12 | dien bien
# City not found. Skipping...
# Processing Record 50 of Set 12 | leua
# Processing Record 1 of Set 13 | aguimes
# Processing Record 2 of Set 13 | harper
# Processing Record 3 of Set 13 | mugur-aksy
# Processing Record 4 of Set 13 | teguise
# Processing Record 5 of Set 13 | kijang
# Processing Record 6 of Set 13 | kununurra
# Processing Record 7 of Set 13 | asuncion ixtaltepec
# Processing Record 8 of Set 13 | antsohihy
# Processing Record 9 of Set 13 | sistranda
# Processing Record 10 of Set 13 | asyut
# Processing Record 11 of Set 13 | turukhansk
# Processing Record 12 of Set 13 | huangpi
# Processing Record 13 of Set 13 | bababe
# City not found. Skipping...
# Processing Record 14 of Set 13 | biloela
# Processing Record 15 of Set 13 | geraldton
# Processing Record 16 of Set 13 | somotillo
# Processing Record 17 of Set 13 | mareeba
# Processing Record 18 of Set 13 | ankazoabo
# Processing Record 19 of Set 13 | teya
# Processing Record 20 of Set 13 | pelym
# Processing Record 21 of Set 13 | vostochnyy
# Processing Record 22 of Set 13 | kimberley
# Processing Record 23 of Set 13 | oriximina
# Processing Record 24 of Set 13 | yumen
# Processing Record 25 of Set 13 | aksarka
# Processing Record 26 of Set 13 | roma
# Processing Record 27 of Set 13 | maragogi
# Processing Record 28 of Set 13 | sao raimundo das mangabeiras
# Processing Record 29 of Set 13 | shimoda
# Processing Record 30 of Set 13 | tazovskiy
# Processing Record 31 of Set 13 | shambu
# Processing Record 32 of Set 13 | afmadu
# City not found. Skipping...
# Processing Record 33 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 13 | gari
# Processing Record 35 of Set 13 | santiago
# Processing Record 36 of Set 13 | kirakira
# Processing Record 37 of Set 13 | udachnyy
# Processing Record 38 of Set 13 | yinchuan
# Processing Record 39 of Set 13 | san javier
# Processing Record 40 of Set 13 | sangar
# Processing Record 41 of Set 13 | swan hill
# Processing Record 42 of Set 13 | shangrao
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_total = len(city_data)

# %%
print(city_weather)
# Out:
# {'coord': {'lon': 117.97, 'lat': 28.45}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 61.25, 'feels_like': 60.13, 'temp_min': 61.25, 'temp_max': 61.25, 'pressure': 1020, 'humidity': 61, 'sea_level': 1020, 'grnd_level': 1009}, 'wind': {'speed': 1.05, 'deg': 154}, 'clouds': {'all': 100}, 'dt': 1587773950, 'sys': {'country': 'CN', 'sunrise': 1587763963, 'sunset': 1587811147}, 'timezone': 28800, 'id': 1787858, 'name': 'Shangrao', 'cod': 200}

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Zhangye  38.93  100.45     49.15        17           0        6.02
# 1         Rikitea -23.12 -134.97     76.98        68          96        8.50
# 2     Provideniya  64.38 -173.30     29.34        92           1       10.16
# 3         Ushuaia -54.80  -68.30     37.40        64          75        9.17
# 4     Henties Bay -22.12   14.28     57.00        96          66        1.01
# 5  Saint-Philippe -21.36   55.77     75.20        83          75        5.82
# 6    Punta Arenas -53.15  -70.92     41.00        65          20       14.99
# 7          Yevlax  40.61   47.15     42.80        93          90        3.44
# 8        Manicore  -5.81  -61.30     80.60        88          92        0.94
# 9      Port Hardy  50.70 -127.42     57.20        62          90       17.22
#
#   Country          Weather  Rain  Snow                 Date
# 0      CN        clear sky  0.00   0.0  2020-04-25 00:13:22
# 1      PF  overcast clouds  0.00   0.0  2020-04-25 00:12:56
# 2      RU        clear sky  0.00   0.0  2020-04-25 00:14:14
# 3      AR      shower rain  0.00   0.0  2020-04-25 00:16:52
# 4      NA    broken clouds  0.00   0.0  2020-04-25 00:16:52
# 5      RE    broken clouds  0.00   0.0  2020-04-25 00:16:53
# 6      CL       few clouds  0.00   0.0  2020-04-25 00:16:53
# 7      AZ  overcast clouds  0.00   0.0  2020-04-25 00:16:53
# 8      BR       light rain  0.92   0.0  2020-04-25 00:16:54
# 9      CA  overcast clouds  0.00   0.0  2020-04-25 00:16:54

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Weather", "Humidity", "Cloudiness", "Wind Speed", "Rain", "Snow"]

city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#           City Country                 Date    Lat     Lng  Max Temp  \
# 0      Zhangye      CN  2020-04-25 00:13:22  38.93  100.45     49.15
# 1      Rikitea      PF  2020-04-25 00:12:56 -23.12 -134.97     76.98
# 2  Provideniya      RU  2020-04-25 00:14:14  64.38 -173.30     29.34
# 3      Ushuaia      AR  2020-04-25 00:16:52 -54.80  -68.30     37.40
# 4  Henties Bay      NA  2020-04-25 00:16:52 -22.12   14.28     57.00
#
#            Weather  Humidity  Cloudiness  Wind Speed  Rain  Snow
# 0        clear sky        17           0        6.02   0.0   0.0
# 1  overcast clouds        68          96        8.50   0.0   0.0
# 2        clear sky        92           1       10.16   0.0   0.0
# 3      shower rain        64          75        9.17   0.0   0.0
# 4    broken clouds        96          66        1.01   0.0   0.0

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_challenge.csv"

# Export the City_data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
#Counting the number of cities with rain in the last three hours
rain_cities = city_data_df.loc[city_data_df['Rain']>0]
rain_cities
# Out:
#                              City Country                 Date    Lat     Lng  \
# 8                        Manicore      BR  2020-04-25 00:16:54  -5.81  -61.30
# 14                  Alta Floresta      BR  2020-04-25 00:16:56  -9.88  -56.09
# 21                     Bredasdorp      ZA  2020-04-25 00:16:57 -34.53   20.04
# 31                     Butaritari      KI  2020-04-25 00:13:06   3.07  172.79
# 32                        Mataura      NZ  2020-04-25 00:17:00 -46.19  168.86
# ..                            ...     ...                  ...    ...     ...
# 546                          Biak      ID  2020-04-25 00:19:03  -0.91  122.88
# 548                   Sardarshahr      IN  2020-04-25 00:19:03  28.43   74.48
# 571                     Oriximina      BR  2020-04-25 00:19:07  -1.77  -55.87
# 576  Sao Raimundo Das Mangabeiras      BR  2020-04-25 00:19:08  -7.02  -45.48
# 582                      Kirakira      SB  2020-04-25 00:19:09 -10.45  161.92
#
#      Max Temp        Weather  Humidity  Cloudiness  Wind Speed  Rain  Snow
# 8       80.60     light rain        88          92        0.94  0.92   0.0
# 14      74.16     light rain        87          90        0.72  0.45   0.0
# 21      60.80     light rain        93          70        2.24  0.25   0.0
# 31      81.61  moderate rain        82          96       20.11  4.51   0.0
# 32      52.00     light rain        90          60       15.99  1.31   0.0
# ..        ...            ...       ...         ...         ...   ...   ...
# 546     82.17     light rain        72          91        4.47  0.25   0.0
# 548     82.24     light rain        33          32       14.90  0.29   0.0
# 571     77.92     light rain        89          84        2.80  1.74   0.0
# 576     76.28     light rain        80          54        2.19  0.91   0.0
# 582     85.23     light rain        70          83        7.09  1.06   0.0
#
# [86 rows x 12 columns]

# %%
rainy_cities = len(rain_cities)

# %%
percent_rain = rainy_cities / city_total * 100
percent_rain
# Out:
# 14.60101867572156

# %%
#Counting the number of cities with rain in the last three hours
snow_cities = city_data_df.loc[city_data_df['Snow']>0]
snow_cities
# Out:
#                 City Country                 Date    Lat     Lng  Max Temp  \
# 86           Lazarev      RU  2020-04-25 00:17:22  52.23  141.51     29.84
# 145        Ostrovnoy      RU  2020-04-25 00:17:37  68.05   39.51     27.66
# 190   Severo-Kurilsk      RU  2020-04-25 00:17:46  50.68  156.12     32.85
# 231            Aldan      RU  2020-04-25 00:17:54  58.60  125.39     32.09
# 247        De-Kastri      RU  2020-04-25 00:17:57  51.47  140.78     32.29
# 295     Staryy Nadym      RU  2020-04-25 00:18:06  65.61   72.68     25.00
# 329           Mehamn      NO  2020-04-25 00:18:13  71.04   27.85     29.35
# 372           Abalak      RU  2020-04-25 00:18:26  58.13   68.59     30.94
# 378         Chumikan      RU  2020-04-25 00:18:28  54.72  135.31     33.12
# 476  Haines Junction      CA  2020-04-25 00:18:47  60.75 -137.51     37.51
#
#         Weather  Humidity  Cloudiness  Wind Speed  Rain  Snow
# 86   light snow        98         100        3.67   0.0  0.52
# 145  light snow        97         100       15.97   0.0  0.89
# 190  light snow        93          75       13.49   0.0  0.20
# 231  light snow        72         100        6.64   0.0  0.97
# 247  light snow        95         100        4.97   0.0  0.39
# 295  light snow        97          57       10.71   0.0  0.25
# 329        snow        97         100       36.69   0.0  2.28
# 372  light snow        97          70        5.19   0.0  0.84
# 378  light snow        94         100        1.54   0.0  1.14
# 476  light snow        61         100        6.17   0.0  0.12

# %%
snowy_cities = len(snow_cities)
snowy_cities
# Out:
# 10

# %%
percent_snow = snowy_cities / city_total * 100
percent_snow
# Out:
# 1.697792869269949

# %%
print(f"Of {city_total} cities, {rainy_cities} cities have had rain in the last three hours.\n That is {percent_rain} percent of total cities.")
print(f"Of {city_total} cities, {snowy_cities} cities have had rain in the last three hours. \n That is {percent_snow} percent of total cities.")
# Out:
# Of 589 cities, 86 cities have had rain in the last three hours.
#  That is 14.60101867572156 percent of total cities.
# Of 589 cities, 10 cities have had rain in the last three hours.
#  That is 1.697792869269949 percent of total cities.
